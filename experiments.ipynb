# %%
import nltk 
nltk.download('gutenberg')
from nltk.corpus import gutenberg
import pandas as pandas

data=gutenberg.raw('shakespeare-hamlet.txt')

with open('hamlet.txt','w') as file:
    file.write(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import nltk
#       2 nltk.download('gutenberg')
#       3 from nltk.corpus import gutenberg
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\nltk\__init__.py:146
#     140 from nltk.jsontags import *
#     142 ###########################################################
#     143 # PACKAGES
#     144 ###########################################################
# --> 146 from nltk.chunk import *
#     147 from nltk.classify import *
#     148 from nltk.inference import *
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\nltk\chunk\__init__.py:155
#       1 # Natural Language Toolkit: Chunkers
#       2 #
#       3 # Copyright (C) 2001-2024 NLTK Project
#    (...)      7 # For license information, see LICENSE.TXT
#       8 #
#      10 """
#      11 Classes and interfaces for identifying non-overlapping linguistic
#      12 groups (such as base noun phrases) in unrestricted text.  This task is
#    (...)    152      pattern is valid.
#     153 """
# --> 155 from nltk.chunk.api import ChunkParserI
#     156 from nltk.chunk.named_entity import Maxent_NE_Chunker
#     157 from nltk.chunk.regexp import RegexpChunkParser, RegexpParser
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\nltk\chunk\api.py:15
#      13 from nltk.chunk.util import ChunkScore
#      14 from nltk.internals import deprecated
# ---> 15 from nltk.parse import ParserI
#      18 class ChunkParserI(ParserI):
#      19     """
#      20     A processing interface for identifying non-overlapping groups in
#      21     unrestricted text.  Typically, chunk parsers are used to find base
#    (...)     24     will always generate a parse.
#      25     """
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\nltk\parse\__init__.py:100
#      95 from nltk.parse.recursivedescent import (
#      96     RecursiveDescentParser,
#      97     SteppingRecursiveDescentParser,
#      98 )
#      99 from nltk.parse.shiftreduce import ShiftReduceParser, SteppingShiftReduceParser
# --> 100 from nltk.parse.transitionparser import TransitionParser
#     101 from nltk.parse.util import TestGrammar, extract_test_sentences, load_parser
#     102 from nltk.parse.viterbi import ViterbiParser
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\nltk\parse\transitionparser.py:18
#      16     from numpy import array
#      17     from scipy import sparse
# ---> 18     from sklearn import svm
#      19     from sklearn.datasets import load_svmlight_file
#      20 except ImportError:
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\sklearn\__init__.py:133, in __getattr__(name)
#     131 def __getattr__(name):
#     132     if name in _submodules:
# --> 133         return _importlib.import_module(f"sklearn.{name}")
#     134     else:
#     135         try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\sklearn\svm\__init__.py:10
#       3 # See http://scikit-learn.sourceforge.net/modules/svm.html for complete
#       4 # documentation.
#       5
#       6 # Authors: The scikit-learn developers
#       7 # SPDX-License-Identifier: BSD-3-Clause
#       9 from ._bounds import l1_min_c
# ---> 10 from ._classes import SVC, SVR, LinearSVC, LinearSVR, NuSVC, NuSVR, OneClassSVM
#      12 __all__ = [
#      13     "LinearSVC",
#      14     "LinearSVR",
#    (...)     20     "l1_min_c",
#      21 ]
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\sklearn\svm\_classes.py:9
#       6 import numpy as np
#       8 from ..base import BaseEstimator, OutlierMixin, RegressorMixin, _fit_context
# ----> 9 from ..linear_model._base import LinearClassifierMixin, LinearModel, SparseCoefMixin
#      10 from ..utils._param_validation import Interval, StrOptions
#      11 from ..utils.multiclass import check_classification_targets
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\sklearn\linear_model\__init__.py:12
#      10 from ._base import LinearRegression
#      11 from ._bayes import ARDRegression, BayesianRidge
# ---> 12 from ._coordinate_descent import (
#      13     ElasticNet,
#      14     ElasticNetCV,
#      15     Lasso,
#      16     LassoCV,
#      17     MultiTaskElasticNet,
#      18     MultiTaskElasticNetCV,
#      19     MultiTaskLasso,
#      20     MultiTaskLassoCV,
#      21     enet_path,
#      22     lasso_path,
#      23 )
#      24 from ._glm import GammaRegressor, PoissonRegressor, TweedieRegressor
#      25 from ._huber import HuberRegressor
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:18
#      15 from sklearn.utils import metadata_routing
#      17 from ..base import MultiOutputMixin, RegressorMixin, _fit_context
# ---> 18 from ..model_selection import check_cv
#      19 from ..utils import Bunch, check_array, check_scalar
#      20 from ..utils._metadata_requests import (
#      21     MetadataRouter,
#      22     MethodMapping,
#      23     _raise_for_params,
#      24     get_routing_for_object,
#      25 )
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\sklearn\model_selection\__init__.py:8
#       3 # Authors: The scikit-learn developers
#       4 # SPDX-License-Identifier: BSD-3-Clause
#       6 import typing
# ----> 8 from ._classification_threshold import (
#       9     FixedThresholdClassifier,
#      10     TunedThresholdClassifierCV,
#      11 )
#      12 from ._plot import LearningCurveDisplay, ValidationCurveDisplay
#      13 from ._search import GridSearchCV, ParameterGrid, ParameterSampler, RandomizedSearchCV
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\sklearn\model_selection\_classification_threshold.py:17
#       9 from ..base import (
#      10     BaseEstimator,
#      11     ClassifierMixin,
#    (...)     14     clone,
#      15 )
#      16 from ..exceptions import NotFittedError
# ---> 17 from ..metrics import (
#      18     check_scoring,
#      19     get_scorer_names,
#      20 )
#      21 from ..metrics._scorer import (
#      22     _CurveScorer,
#      23     _threshold_scores_to_class_labels,
#      24 )
#      25 from ..utils import _safe_indexing, get_tags
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\sklearn\metrics\__init__.py:6
#       1 """Score functions, performance metrics, pairwise metrics and distance computations."""
#       3 # Authors: The scikit-learn developers
#       4 # SPDX-License-Identifier: BSD-3-Clause
# ----> 6 from . import cluster
#       7 from ._classification import (
#       8     accuracy_score,
#       9     balanced_accuracy_score,
#    (...)     27     zero_one_loss,
#      28 )
#      29 from ._dist_metrics import DistanceMetric
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\sklearn\metrics\cluster\__init__.py:28
#      11 from ._bicluster import consensus_score
#      12 from ._supervised import (
#      13     adjusted_mutual_info_score,
#      14     adjusted_rand_score,
#    (...)     26     v_measure_score,
#      27 )
# ---> 28 from ._unsupervised import (
#      29     calinski_harabasz_score,
#      30     davies_bouldin_score,
#      31     silhouette_samples,
#      32     silhouette_score,
#      33 )
#      35 __all__ = [
#      36     "adjusted_mutual_info_score",
#      37     "normalized_mutual_info_score",
#    (...)     54     "consensus_score",
#      55 ]
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:21
#      15 from ...utils._array_api import _atol_for_type
#      16 from ...utils._param_validation import (
#      17     Interval,
#      18     StrOptions,
#      19     validate_params,
#      20 )
# ---> 21 from ..pairwise import _VALID_METRICS, pairwise_distances, pairwise_distances_chunked
#      24 def check_number_of_labels(n_labels, n_samples):
#      25     """Check that number of labels are valid.
#      26
#      27     Parameters
#    (...)     33         Number of samples.
#      34     """
#
# File c:\Users\njana\Pictures\LSTM\myenv\Lib\site-packages\sklearn\metrics\pairwise.py:47
#      45 from ..utils.validation import _num_samples, check_non_negative
#      46 from ._pairwise_distances_reduction import ArgKmin
# ---> 47 from ._pairwise_fast import _chi2_kernel_fast, _sparse_manhattan
#      50 # Utility Functions
#      51 def _return_float_dtype(X, Y):
#
# File <frozen importlib._bootstrap>:645, in parent(self)
#
# KeyboardInterrupt:
